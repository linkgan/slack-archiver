# %%
import logging
import creds
import pandas as pd
from archive import Archive

pd.options.display.max_columns = 50

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %%
a = Archive(token=creds.bot_token)
a.full_run()
# Out:
# INFO:root:Initializing Archive object
# INFO:root:Getting conversation history
# INFO:root:Saving conversation history to gsheet for [general]
# INFO:root:Getting conversation history
# INFO:root:Saving conversation history to gsheet for [kids]

# %%
a.get_conversation_history(a.channel_dict[a.channels_to_archive[0]])
# Out:
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is archiver
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is ellenmccullagh
# Username for USER_ID is ellenmccullagh
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is gan.link
# Username for USER_ID is ellenmccullagh
# Username for USER_ID is lgan
# Username for USER_ID is gan.link

# %%
a.df.head()
# Out:
#                           client_msg_id     type  \
# 0  4276e897-0dd7-423f-875e-d110db409217  message
# 1  38863052-185f-49dd-a201-e48df479d585  message
# 2  51913c71-9bcf-4f0e-a2db-ffa4e3e1195f  message
# 3  3a7583e5-b079-42af-882f-95dd5b13f16e  message
# 4  662afabf-bda9-41b9-8b36-da2cddc98013  message
#
#                                                 text         user  \
# 0  wells fargo active cash visa application: *Ref...  U04PDFDS2UA
# 1         dmv apt confirmation: 231-685-105 for Nini  U04PDFDS2UA
# 2  dmv apt confirmation: 231-657-972 under (Sheng...  U04PDFDS2UA
# 3  create account online: <http://benefitscal.com...  U04PDFDS2UA
# 4                      medi-cal case number: L366E27  U04PDFDS2UA
#
#                   ts                                             blocks  \
# 0  1680200047.992859  [{'type': 'rich_text', 'block_id': 'UlSAa', 'e...
# 1  1680198469.924729  [{'type': 'rich_text', 'block_id': 'NrR', 'ele...
# 2  1680198362.222819  [{'type': 'rich_text', 'block_id': '+X=VL', 'e...
# 3  1680133174.483779  [{'type': 'rich_text', 'block_id': 'VXOO', 'el...
# 4  1680132816.167899  [{'type': 'rich_text', 'block_id': 'IZ5Y', 'el...
#
#           team                                             edited files  \
# 0  T04Q367017S                                                NaN   NaN
# 1  T04Q367017S                                                NaN   NaN
# 2  T04Q367017S  {'user': 'U04PDFDS2UA', 'ts': '1680198373.0000...   NaN
# 3  T04Q367017S                                                NaN   NaN
# 4  T04Q367017S                                                NaN   NaN
#
#   upload display_as_bot subtype inviter thread_ts  reply_count  \
# 0    NaN            NaN     NaN     NaN       NaN          NaN
# 1    NaN            NaN     NaN     NaN       NaN          NaN
# 2    NaN            NaN     NaN     NaN       NaN          NaN
# 3    NaN            NaN     NaN     NaN       NaN          NaN
# 4    NaN            NaN     NaN     NaN       NaN          NaN
#
#    reply_users_count latest_reply reply_users is_locked subscribed reactions  \
# 0                NaN          NaN         NaN       NaN        NaN       NaN
# 1                NaN          NaN         NaN       NaN        NaN       NaN
# 2                NaN          NaN         NaN       NaN        NaN       NaN
# 3                NaN          NaN         NaN       NaN        NaN       NaN
# 4                NaN          NaN         NaN       NaN        NaN       NaN
#
#                   readable_time        date  archive_time  username
# 0 2023-03-30 18:14:07.992858887  2023-03-30  1.680568e+09  gan.link
# 1 2023-03-30 17:47:49.924729109  2023-03-30  1.680568e+09  gan.link
# 2 2023-03-30 17:46:02.222819090  2023-03-30  1.680568e+09  gan.link
# 3 2023-03-29 23:39:34.483778954  2023-03-29  1.680568e+09  gan.link
# 4 2023-03-29 23:33:36.167898893  2023-03-29  1.680568e+09  gan.link

# %%
# Fetch all threads in a channel
conversation_id = None
try:
    # Call the conversations.list method using the WebClient
    for result in client.conversations_list():
        if conversation_id is not None:
            break
        for channel in result["channels"]:
            if channel["name"] == channel_name:
                conversation_id = channel["id"]
                #Print result
                print(channel['id'])
                print(f"Found conversation ID: {conversation_id}")
                break

except SlackApiError as e:
    print(f"Error: {e}")
# Out:
# C04PDBY2ZGB
# Found conversation ID: C04PDBY2ZGB

# %%
channel_id = 'C04PDBY2ZGB'

# %%
# Store conversation history
conversation_history = []
# ID of the channel you want to send the message to

try:
    # Call the conversations.history method using the WebClient
    # conversations.history returns the first 100 messages by default
    # These results are paginated, see: https://api.slack.com/methods/conversations.history$pagination
    result = client.conversations_history(channel=channel_id)

    conversation_history = result["messages"]
    pprint.pprint(conversation_history)
    # Print results
    logger.info("{} messages found in {}".format(len(conversation_history), channel_id))

except SlackApiError as e:
    logger.error("Error creating conversation: {}".format(e))
# Out:
# [{'blocks': [{'block_id': 'eiXC',
#               'elements': [{'elements': [{'text': 'test test', 'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': '8d812905-bc20-447a-b2cc-1be20611483a',
#   'team': 'T04Q367017S',
#   'text': 'test test',
#   'ts': '1680126902.966649',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'AOFy',
#               'elements': [{'elements': [{'text': 'drivers license application '
#                                                   'confirmation code',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'fd8cb18b-2677-4146-8710-a79ddde58709',
#   'display_as_bot': False,
#   'files': [{'created': 1680116583,
#              'display_as_bot': False,
#              'editable': False,
#              'external_type': '',
#              'file_access': 'visible',
#              'filetype': 'png',
#              'has_rich_preview': False,
#              'id': 'F050WLWC98T',
#              'is_external': False,
#              'is_public': True,
#              'is_starred': False,
#              'media_display_type': 'unknown',
#              'mimetype': 'image/png',
#              'mode': 'hosted',
#              'name': 'Screen Shot 2023-03-29 at 12.02.45 PM.png',
#              'original_h': 1034,
#              'original_w': 966,
#              'permalink': 'https://mccullagh-gan.slack.com/files/U04PDFDS2UA/F050WLWC98T/screen_shot_2023-03-29_at_12.02.45_pm.png',
#              'permalink_public': 'https://slack-files.com/T04Q367017S-F050WLWC98T-762d74aa0a',
#              'pretty_type': 'PNG',
#              'public_url_shared': False,
#              'size': 81306,
#              'thumb_1024': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_1024.png',
#              'thumb_1024_h': 1024,
#              'thumb_1024_w': 957,
#              'thumb_160': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_160.png',
#              'thumb_360': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_360.png',
#              'thumb_360_h': 360,
#              'thumb_360_w': 336,
#              'thumb_480': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_480.png',
#              'thumb_480_h': 480,
#              'thumb_480_w': 448,
#              'thumb_64': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_64.png',
#              'thumb_720': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_720.png',
#              'thumb_720_h': 720,
#              'thumb_720_w': 673,
#              'thumb_80': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_80.png',
#              'thumb_800': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_800.png',
#              'thumb_800_h': 856,
#              'thumb_800_w': 800,
#              'thumb_960': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_960.png',
#              'thumb_960_h': 960,
#              'thumb_960_w': 897,
#              'thumb_tiny': 'AwAwACzQx7N+dOyf7poJIPf8qWgBM/7JoByehFKaQGgBaKKKAIJJlWTaQcj2qfmiimIDQKKKQwooooAafvcfyp1NKknPFOxigBD0oH+eKWigAooooA//2Q==',
#              'timestamp': 1680116583,
#              'title': 'Screen Shot 2023-03-29 at 12.02.45 PM.png',
#              'url_private': 'https://files.slack.com/files-pri/T04Q367017S-F050WLWC98T/screen_shot_2023-03-29_at_12.02.45_pm.png',
#              'url_private_download': 'https://files.slack.com/files-pri/T04Q367017S-F050WLWC98T/download/screen_shot_2023-03-29_at_12.02.45_pm.png',
#              'user': 'U04PDFDS2UA',
#              'user_team': 'T04Q367017S',
#              'username': ''}],
#   'text': 'drivers license application confirmation code',
#   'ts': '1680116592.267059',
#   'type': 'message',
#   'upload': False,
#   'user': 'U04PDFDS2UA'},
#  {'inviter': 'U04PDFDS2UA',
#   'subtype': 'channel_join',
#   'text': '<@U050SVD51RT> has joined the channel',
#   'ts': '1680113909.799519',
#   'type': 'message',
#   'user': 'U050SVD51RT'},
#  {'blocks': [{'block_id': 'wx6',
#               'elements': [{'elements': [{'text': 'Go to covered California '
#                                                   'office on hillhurst ',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'F5F124DA-65E9-4CDE-A4FA-EF5105DF5FF9',
#   'is_locked': False,
#   'latest_reply': '1678299216.117509',
#   'reply_count': 1,
#   'reply_users': ['U04PDFJBS10'],
#   'reply_users_count': 1,
#   'subscribed': False,
#   'team': 'T04Q367017S',
#   'text': 'Go to covered California office on hillhurst ',
#   'thread_ts': '1678299163.177969',
#   'ts': '1678299163.177969',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'qPX/=',
#               'elements': [{'elements': [{'text': 'make covid apts',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'cf6d3d91-10b9-4a95-aa42-8b8ff94b8b05',
#   'reactions': [{'count': 1,
#                  'name': 'white_check_mark',
#                  'users': ['U04PDFDS2UA']}],
#   'team': 'T04Q367017S',
#   'text': 'make covid apts',
#   'ts': '1678224188.726929',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': '7=Yr',
#               'elements': [{'elements': [{'text': 'just taking notes',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': '3ff9a418-d867-484e-8794-6c699e46f2c0',
#   'team': 'T04Q367017S',
#   'text': 'just taking notes',
#   'ts': '1678135827.532419',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'Rop',
#               'elements': [{'elements': [{'text': 'I', 'type': 'text'},
#                                          {'text': ' trust you',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'FBF270AB-1500-4DF3-956F-788EF5ED9F3E',
#   'team': 'T04Q367017S',
#   'text': 'I trust you',
#   'ts': '1678135822.952549',
#   'type': 'message',
#   'user': 'U04PDFJBS10'},
#  {'blocks': [{'block_id': 'k1E',
#               'elements': [{'elements': [{'text': 'Huh?', 'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': '5EFCCB41-184B-47E6-BEF9-C945979F1FC3',
#   'team': 'T04Q367017S',
#   'text': 'Huh?',
#   'ts': '1678135818.529489',
#   'type': 'message',
#   'user': 'U04PDFJBS10'},
#  {'blocks': [{'block_id': 'TT1',
#               'elements': [{'elements': [{'text': 'subaru 30k service would '
#                                                   'cost 460…not gonna do it '
#                                                   'today',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': '2518f20d-d749-462d-a575-029593170d11',
#   'team': 'T04Q367017S',
#   'text': 'subaru 30k service would cost 460…not gonna do it today',
#   'ts': '1678135800.388499',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'mLPy',
#               'elements': [{'elements': [{'text': 'drivers license',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'cfebfa3f-0432-4a15-98ad-ffe0a9901142',
#   'team': 'T04Q367017S',
#   'text': 'drivers license',
#   'ts': '1678119666.583389',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'YeCMS',
#               'elements': [{'elements': [{'text': 'Cellphone ',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'B8E2414F-7362-4735-B601-707CF4331C78',
#   'team': 'T04Q367017S',
#   'text': 'Cellphone ',
#   'ts': '1678049410.107799',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'TGmw',
#               'elements': [{'elements': [{'text': 'Neighbors and religion ',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'B5A04C9E-51D0-46E3-A561-D934B53849A5',
#   'team': 'T04Q367017S',
#   'text': 'Neighbors and religion ',
#   'ts': '1678049406.006509',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'aWwF',
#               'elements': [{'elements': [{'text': 'Cleaning and laundry stuff',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'A7E87310-C69A-478E-A67C-1FCBB2D88D46',
#   'team': 'T04Q367017S',
#   'text': 'Cleaning and laundry stuff',
#   'ts': '1678047649.253149',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'bLIBN',
#               'elements': [{'elements': [{'text': 'Groceries and food plan',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'A1A31523-8CF5-415D-A065-9492BA2B18BC',
#   'team': 'T04Q367017S',
#   'text': 'Groceries and food plan',
#   'ts': '1678047633.819059',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': '+lT6',
#               'elements': [{'elements': [{'text': 'Getting a car',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'FFE510BF-E6AE-497E-8364-8957805AEEC6',
#   'team': 'T04Q367017S',
#   'text': 'Getting a car',
#   'ts': '1678047622.660499',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'FOo2P',
#               'elements': [{'elements': [{'text': 'Expectations on child care',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': '9BC43FAF-6C0B-4515-AA24-BCC6E5841E3E',
#   'team': 'T04Q367017S',
#   'text': 'Expectations on child care',
#   'ts': '1678047551.513779',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'JFz6V',
#               'elements': [{'elements': [{'text': 'Get health insurancr',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': '022C6F37-A53A-4DB5-9184-BA316F5190F4',
#   'edited': {'ts': '1678047568.000000', 'user': 'U04PDFDS2UA'},
#   'team': 'T04Q367017S',
#   'text': 'Get health insurancr',
#   'ts': '1678047544.866079',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': '=N9Kk',
#               'elements': [{'elements': [{'text': 'Expectations on food',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': '4484FCBD-3E72-4437-9492-07154E834C0F',
#   'team': 'T04Q367017S',
#   'text': 'Expectations on food',
#   'ts': '1678047539.100629',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': 'yMV7f',
#               'elements': [{'elements': [{'text': 'House budget and timeline',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': '8B841593-BDC5-4B2A-9F67-D58FAE9C5728',
#   'team': 'T04Q367017S',
#   'text': 'House budget and timeline',
#   'ts': '1678047528.482769',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': '1Fyp',
#               'elements': [{'elements': [{'text': 'Things to talk to my '
#                                                   'parents about',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': 'F557A01E-AA08-40CA-AB67-88737E8A0692',
#   'team': 'T04Q367017S',
#   'text': 'Things to talk to my parents about',
#   'ts': '1678047522.276799',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'blocks': [{'block_id': '4WHMP',
#               'elements': [{'elements': [{'text': 'reminder to check Fubo '
#                                                   'subscription in 6 months',
#                                           'type': 'text'}],
#                             'type': 'rich_text_section'}],
#               'type': 'rich_text'}],
#   'client_msg_id': '8b0f4873-ea70-45d8-9e59-1cf08d346bf8',
#   'team': 'T04Q367017S',
#   'text': 'reminder to check Fubo subscription in 6 months',
#   'ts': '1678047514.431399',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'},
#  {'subtype': 'channel_join',
#   'text': '<@U04PDFJBS10> has joined the channel',
#   'ts': '1676320327.390459',
#   'type': 'message',
#   'user': 'U04PDFJBS10'},
#  {'subtype': 'channel_join',
#   'text': '<@U04PDGM8K27> has joined the channel',
#   'ts': '1676316574.961829',
#   'type': 'message',
#   'user': 'U04PDGM8K27'},
#  {'subtype': 'channel_join',
#   'text': '<@U04PDFDS2UA> has joined the channel',
#   'ts': '1676314910.502419',
#   'type': 'message',
#   'user': 'U04PDFDS2UA'}]

# %%
conversation_id = None

try:
    # Call the conversations.list method using the WebClient
    for result in client.conversations_list():
        # if conversation_id is not None:
        #     break
        for channel in result["channels"]:
            if channel["name"] == channel_name:
                conversation_id = channel["id"]
                #Print result
                print(f"Found conversation ID: {conversation_id}")
                # break

except SlackApiError as e:
    print(f"Error: {e}")
# Out:
# Found conversation ID: C04PDBY2ZGB

# %%
# ID of channel that the message exists in
conversation_id = "C04PDBY2ZGB"

try:
    # Call the conversations.history method using the WebClient
    # The client passes the token you included in initialization    
    result = client.conversations_history(
        channel=conversation_id,
        inclusive=True,
        limit=100
    )
    
    print(result)

    message = result["messages"][0]
    # Print message text
    print(message["text"])

except SlackApiError as e:
    print(f"Error: {e}")
# Out:
# {'ok': True, 'messages': [{'client_msg_id': '8d812905-bc20-447a-b2cc-1be20611483a', 'type': 'message', 'text': 'test test', 'user': 'U04PDFDS2UA', 'ts': '1680126902.966649', 'blocks': [{'type': 'rich_text', 'block_id': 'eiXC', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'test test'}]}]}], 'team': 'T04Q367017S'}, {'type': 'message', 'text': 'drivers license application confirmation code', 'files': [{'id': 'F050WLWC98T', 'created': 1680116583, 'timestamp': 1680116583, 'name': 'Screen Shot 2023-03-29 at 12.02.45 PM.png', 'title': 'Screen Shot 2023-03-29 at 12.02.45 PM.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U04PDFDS2UA', 'user_team': 'T04Q367017S', 'editable': False, 'size': 81306, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T04Q367017S-F050WLWC98T/screen_shot_2023-03-29_at_12.02.45_pm.png', 'url_private_download': 'https://files.slack.com/files-pri/T04Q367017S-F050WLWC98T/download/screen_shot_2023-03-29_at_12.02.45_pm.png', 'media_display_type': 'unknown', 'thumb_64': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_64.png', 'thumb_80': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_80.png', 'thumb_360': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_360.png', 'thumb_360_w': 336, 'thumb_360_h': 360, 'thumb_480': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_480.png', 'thumb_480_w': 448, 'thumb_480_h': 480, 'thumb_160': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_160.png', 'thumb_720': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_720.png', 'thumb_720_w': 673, 'thumb_720_h': 720, 'thumb_800': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_800.png', 'thumb_800_w': 800, 'thumb_800_h': 856, 'thumb_960': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_960.png', 'thumb_960_w': 897, 'thumb_960_h': 960, 'thumb_1024': 'https://files.slack.com/files-tmb/T04Q367017S-F050WLWC98T-b6095eff35/screen_shot_2023-03-29_at_12.02.45_pm_1024.png', 'thumb_1024_w': 957, 'thumb_1024_h': 1024, 'original_w': 966, 'original_h': 1034, 'thumb_tiny': 'AwAwACzQx7N+dOyf7poJIPf8qWgBM/7JoByehFKaQGgBaKKKAIJJlWTaQcj2qfmiimIDQKKKQwooooAafvcfyp1NKknPFOxigBD0oH+eKWigAooooA//2Q==', 'permalink': 'https://mccullagh-gan.slack.com/files/U04PDFDS2UA/F050WLWC98T/screen_shot_2023-03-29_at_12.02.45_pm.png', 'permalink_public': 'https://slack-files.com/T04Q367017S-F050WLWC98T-762d74aa0a', 'is_starred': False, 'has_rich_preview': False, 'file_access': 'visible'}], 'upload': False, 'user': 'U04PDFDS2UA', 'display_as_bot': False, 'ts': '1680116592.267059', 'blocks': [{'type': 'rich_text', 'block_id': 'AOFy', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'drivers license application confirmation code'}]}]}], 'client_msg_id': 'fd8cb18b-2677-4146-8710-a79ddde58709'}, {'type': 'message', 'subtype': 'channel_join', 'ts': '1680113909.799519', 'user': 'U050SVD51RT', 'text': '<@U050SVD51RT> has joined the channel', 'inviter': 'U04PDFDS2UA'}, {'client_msg_id': 'F5F124DA-65E9-4CDE-A4FA-EF5105DF5FF9', 'type': 'message', 'text': 'Go to covered California office on hillhurst ', 'user': 'U04PDFDS2UA', 'ts': '1678299163.177969', 'blocks': [{'type': 'rich_text', 'block_id': 'wx6', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Go to covered California office on hillhurst '}]}]}], 'team': 'T04Q367017S', 'thread_ts': '16 ...
# test test
